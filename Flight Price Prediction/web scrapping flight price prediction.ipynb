# %%
import time
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.by import By
import pandas as pd
import warnings
warnings.filterwarnings('ignore')
from selenium.common.exceptions import NoSuchElementException,WebDriverException,ElementClickInterceptedException,ElementNotInteractableException,StaleElementReferenceException
from selenium.webdriver.chrome.options import Options

# %%
option = Options()
option.add_argument('--disable-notifications')
PATH = 'chromedriver.exe'
driver = webdriver.Chrome(PATH,chrome_options=option)
driver.maximize_window()

# %%
def data_ready_to_scrap(departure_destination,arrival_destination):
    driver.get('https://www.google.com/travel/flights?tcfs&ved=2ahUKEwjxzpjlmPn4AhW4wYQAHcloA_sQyJABegQIABAX&ictx=2')
    time.sleep(2)
    driver.find_element_by_xpath('/html/body/c-wiz[2]/div/div[2]/c-wiz/div/c-wiz/div[2]/div[1]/div[1]/div[1]/div/div[1]/div[1]/div/div[1]/div[1]/div/button/span[2]').click()
    driver.find_element_by_xpath('/html/body/c-wiz[2]/div/div[2]/c-wiz/div/c-wiz/div[2]/div[1]/div[1]/div[1]/div/div[1]/div[1]/div/div[1]/div[2]/div[2]/ul/li[2]').click()
    time.sleep(1)
    driver.find_element_by_xpath('/html/body/c-wiz[2]/div/div[2]/c-wiz/div/c-wiz/div[2]/div[1]/div[1]/div[1]/div/div[2]/div[1]/div[1]/div/div/div[1]/div/div/input').clear()
    driver.find_element_by_xpath('/html/body/c-wiz[2]/div/div[2]/c-wiz/div/c-wiz/div[2]/div[1]/div[1]/div[1]/div/div[2]/div[1]/div[1]/div/div/div[1]/div/div/input').click()
    driver.find_element_by_xpath('/html/body/c-wiz[2]/div/div[2]/c-wiz/div/c-wiz/div[2]/div[1]/div[1]/div[1]/div/div[2]/div[1]/div[6]/div[2]/div[2]/div[1]/div/input').send_keys(departure_destination)
    time.sleep(1)
    driver.find_element_by_xpath('/html/body/c-wiz[2]/div/div[2]/c-wiz/div/c-wiz/div[2]/div[1]/div[1]/div[1]/div/div[2]/div[1]/div[6]/div[3]/ul/li[1]/div[2]').click()
    time.sleep(0.5)
    driver.find_element_by_xpath('/html/body/c-wiz[2]/div/div[2]/c-wiz/div/c-wiz/div[2]/div[1]/div[1]/div[1]/div/div[2]/div[1]/div[4]/div/div/div[1]/div/div/input').click()
    driver.find_element_by_xpath('/html/body/c-wiz[2]/div/div[2]/c-wiz/div/c-wiz/div[2]/div[1]/div[1]/div[1]/div/div[2]/div[1]/div[6]/div[2]/div[2]/div[1]/div/input').send_keys(arrival_destination)
    time.sleep(1)
    driver.find_element_by_xpath('/html/body/c-wiz[2]/div/div[2]/c-wiz/div/c-wiz/div[2]/div[1]/div[1]/div[1]/div/div[2]/div[1]/div[6]/div[3]/ul/li[1]/div[2]').click()
    time.sleep(2)
    driver.find_element_by_xpath('//*[@id="yDmH0d"]/c-wiz[2]/div/div[2]/c-wiz/div/c-wiz/div[2]/div[1]/div[1]/div[1]/div/div[2]/div[2]/div/div/div[1]/div/div/div[1]/div/div[1]/div/input').click()
    driver.find_element_by_xpath('/html/body/c-wiz[2]/div/div[2]/c-wiz/div/c-wiz/div[2]/div[1]/div[1]/div[1]/div/div[2]/div[2]/div/div/div[2]/div/div[2]/div[2]/div/div/div[1]/div/div/div[1]/div[3]/div[3]/div[6]/div').click()
    time.sleep(2)
    driver.find_element_by_xpath('/html/body/c-wiz[2]/div/div[2]/c-wiz/div/c-wiz/div[2]/div[1]/div[1]/div[1]/div/div[2]/div[2]/div/div/div[2]/div/div[3]/div[3]/div/button').click()
    time.sleep(3)
    driver.find_element_by_xpath('/html/body/c-wiz[2]/div/div[2]/c-wiz/div/c-wiz/div[2]/div[1]/div/div[4]/div/div/div[2]/div[1]/div/div[1]/span/button/span').click()
    time.sleep(1)
    driver.find_element_by_xpath('/html/body/c-wiz[2]/div/div[2]/c-wiz/div/c-wiz/div[2]/div[1]/div/div[4]/div/div[2]/div[3]/div/div[1]/section/div[2]/div[1]/div/div/div[3]/div/input').click()
    time.sleep(2)
    driver.find_element_by_xpath('/html/body/c-wiz[2]/div/div[2]/c-wiz/div/c-wiz/div[2]/div[1]/div/div[4]/div/div[2]/div[3]/div/div[1]/section/div[1]/span/button').click()
    # Load more flights
    time.sleep(1)
    for i in range(0,10):
        driver.execute_script("window.scrollTo(0, window.scrollY + 2000)")
        time.sleep(0.2)
    driver.find_element_by_xpath('//button[@class="VfPpkd-LgbsSe VfPpkd-LgbsSe-OWXEXe-k8QpJ VfPpkd-LgbsSe-OWXEXe-Bz112c-M1Soyc VfPpkd-LgbsSe-OWXEXe-dgl2Hf nCP5yc AjY5Oe LQeN7 nJawce OTelKf iIo4pd"]').click()
    time.sleep(5)

# %%
def feature_extration():
    for i in range(0,61):
        main = driver.find_elements_by_xpath('//div[@class="TQqf0e sSHqwe tPgKwe ogfYpf"]')
        for i in main:
            airline =i.text
            Airline.append(airline)
            date = driver.find_element_by_xpath('/html/body/c-wiz[2]/div/div[2]/c-wiz/div/c-wiz/div[2]/div[2]/div[2]/div[1]/div/div[1]/label[1]/span[1]/div').text
            Date.append(date)

        main = driver.find_elements_by_xpath('//div[@class="zxVSec YMlIz tPgKwe ogfYpf"]')
        for i in main:
            try:
                departure = i.text.split('\n')[0]
                Departure.append(departure)
            except:
                Departure.append('-')
            try:
                arrival = i.text.split('\n')[2]
                Arrival.append(arrival)
            except:
                Arrival.append('-')
                

        main = driver.find_elements_by_xpath('//div[@class="gvkrdb AdWm1c tPgKwe ogfYpf"]')
        for i in main:
            try:
                duration = i.text
                Duration.append(duration)
            except:
                Duration.append('-')

        main = driver.find_elements_by_xpath('//span[@class="z0fuv sSHqwe tPgKwe ogfYpf"]')
        for i in main:
            try:
                route = i.text
                Route.append(route)
            except:
                Route.append('-')

        main = driver.find_elements_by_xpath('//div[@class="BbR8Ec"]')
        for i in main:
            try:
                stop = i.text.split('\n')[0]
                Stops.append(stop)
            except:
                Stops.append('-')
            try:
                layover = i.text.split('\n')[1].split(' ')[-1]
                Layover.append(layover)
            except:
                Layover.append("-")
            try:
                layover_time = i.text.split('\n')[1].split(' ')[:-1]
                layover_time = ' '.join(layover_time)
                Layover_Time.append(layover_time)
            except:
                Layover_Time.append('-')

        main = driver.find_elements_by_xpath('//div[@class="y0NSEe V1iAHe tPgKwe ogfYpf"]')
        for i in main:
            try:
                co2 = i.text.split('\n')[0]
                Co2.append(co2)
            except:
                Co2.append('-')
            try:
                emission = i.text.split('\n')[1]
                Emissions.append(emission)
            except:
                Emissions.append("-")

        main = driver.find_elements_by_xpath('//div[@class="U3gSDe"]')
        for i in main:
            try:
                price = i.text
                Price.append(price)
            except:
                Price.append('-')

        ref = driver.current_url
        driver.get(ref)
        try:
            driver.find_element_by_xpath('/html/body/c-wiz[2]/div/div[2]/c-wiz/div/c-wiz/div[2]/div[1]/div/div[2]/div[2]/div/div/div[1]/div/div/div[1]/div/div[1]/div/div[3]/button').click()
        except:
            ref = driver.current_url
            driver.get(ref)
            pass
        time.sleep(6)

# %%
data_ready_to_scrap('Mumbai','Delhi')

# %%
Date = []
Airline = []
Departure = []
Arrival = []
Duration = []
Route = []
Stops = []
Layover = []
Layover_Time = []
Co2 = []
Emissions = []
Price = []

# %%
feature_extration()

# %%
Mum_Del = pd.DataFrame()
Mum_Del['Date'] = Date
Mum_Del['Airline']=Airline
Mum_Del['Departure']=Departure
Mum_Del['Arrival']=Arrival
Mum_Del['Duration']=Duration
Mum_Del['Route']=Route
Mum_Del['Stops']=Stops
Mum_Del['Layover']=Layover
Mum_Del['Layover_Time']=Layover_Time
Mum_Del['Co2']=Co2
Mum_Del['Emissions']=Emissions
Mum_Del['Price']=Price
Mum_Del
# Out:
#         Date                Airline Departure    Arrival      Duration  \
# 0     Aug 15               SpiceJet  12:35 AM    3:00 AM   2 hr 25 min
# 1     Aug 15               GO FIRST   8:05 AM   10:15 AM   2 hr 10 min
# 2     Aug 15                Vistara   7:30 AM    9:35 AM    2 hr 5 min
# 3     Aug 15        AirAsia (India)   3:25 PM   11:10 PM   7 hr 45 min
# 4     Aug 15               GO FIRST   6:00 AM    8:05 AM    2 hr 5 min
# ...      ...                    ...       ...        ...           ...
# 1093  Aug 17    IndiGoQatar Airways   6:35 PM  8:40 AM+1   14 hr 5 min
# 1094  Aug 17    IndiGoQatar Airways   4:55 AM  3:15 AM+1  22 hr 20 min
# 1095  Aug 17  IndiGo, Qatar Airways   6:35 PM  8:45 AM+1  14 hr 10 min
# 1096  Aug 17  Qatar Airways, IndiGo   4:25 AM  3:15 AM+1  22 hr 50 min
# 1097  Aug 17                 Etihad   8:55 PM  7:30 PM+1  22 hr 35 min
#
#         Route    Stops Layover  Layover_Time         Co2        Emissions  \
# 0     BOM–DEL  Nonstop       -             -  122 kg CO2   +27% emissions
# 1     BOM–DEL  Nonstop       -             -   83 kg CO2   -12% emissions
# 2     BOM–DEL  Nonstop       -             -  103 kg CO2    +8% emissions
# 3     BOM–DEL   1 stop     JAI   4 hr 50 min  113 kg CO2   +19% emissions
# 4     BOM–DEL  Nonstop       -             -   83 kg CO2   -12% emissions
# ...       ...      ...     ...           ...         ...              ...
# 1093  BOM–DEL   1 stop     DOH   6 hr 30 min  306 kg CO2  +221% emissions
# 1094  BOM–DEL   1 stop     DOH  14 hr 20 min  306 kg CO2  +221% emissions
# 1095  BOM–DEL   1 stop     DOH   6 hr 45 min  323 kg CO2  +240% emissions
# 1096  BOM–DEL   1 stop     DOH  15 hr 15 min  297 kg CO2  +213% emissions
# 1097  BOM–DEL   1 stop     AUH  16 hr 10 min  776 kg CO2  +717% emissions
#
#         Price
# 0      ₹5,365
# 1      ₹5,390
# 2      ₹5,717
# 3      ₹5,164
# 4      ₹5,390
# ...       ...
# 1093  ₹56,280
# 1094  ₹61,872
# 1095  ₹67,494
# 1096  ₹70,193
# 1097  ₹76,234
#
# [1098 rows x 12 columns]

# %%
Mum_Del.to_csv('Flights_Mum_Del1.csv')

# %%
option = Options()
option.add_argument('--disable-notifications')
PATH = 'chromedriver.exe'
driver = webdriver.Chrome(PATH,chrome_options=option)
driver.maximize_window()

# %%
data_ready_to_scrap('Delhi','Mumbai')

# %%
feature_extration()

# %%
Del_Mum = pd.DataFrame()
Del_Mum['Date'] = Date
Del_Mum['Airline']=Airline[:4233]
Del_Mum['Departure']=Departure
Del_Mum['Arrival']=Arrival
Del_Mum['Duration']=Duration
Del_Mum['Route']=Route
Del_Mum['Stops']=Stops
Del_Mum['Layover']=Layover
Del_Mum['Layover_Time']=Layover_Time
Del_Mum['Co2']=Co2
Del_Mum['Emissions']=Emissions
Del_Mum['Price']=Price
Del_Mum
# Out:
#         Date             Airline Departure    Arrival      Duration    Route  \
# 0     Aug 15            SpiceJet  12:35 AM    3:00 AM   2 hr 25 min  BOM–DEL
# 1     Aug 15            GO FIRST   8:05 AM   10:15 AM   2 hr 10 min  BOM–DEL
# 2     Aug 15             Vistara   7:30 AM    9:35 AM    2 hr 5 min  BOM–DEL
# 3     Aug 15     AirAsia (India)   3:25 PM   11:10 PM   7 hr 45 min  BOM–DEL
# 4     Aug 15            GO FIRST   6:00 AM    8:05 AM    2 hr 5 min  BOM–DEL
# ...      ...                 ...       ...        ...           ...      ...
# 4228  Aug 15              Saudia   4:20 AM    5:45 PM  13 hr 25 min  DEL–BOM
# 4229  Aug 15              Saudia  10:05 AM  1:20 PM+1  27 hr 15 min  DEL–BOM
# 4230  Aug 15            Gulf Air  10:35 AM  2:55 AM+1  16 hr 20 min  DEL–BOM
# 4231  Aug 15            Gulf Air   4:10 AM    2:10 PM         10 hr  DEL–BOM
# 4232  Aug 15  flydubai, Emirates   3:25 AM    2:10 PM  10 hr 45 min  DEL–BOM
#
#         Stops Layover  Layover_Time         Co2        Emissions    Price
# 0     Nonstop       -             -  122 kg CO2   +27% emissions   ₹5,365
# 1     Nonstop       -             -   83 kg CO2   -12% emissions   ₹5,390
# 2     Nonstop       -             -  103 kg CO2    +8% emissions   ₹5,717
# 3      1 stop     JAI   4 hr 50 min  113 kg CO2   +19% emissions   ₹5,164
# 4     Nonstop       -             -   83 kg CO2   -12% emissions   ₹5,390
# ...       ...     ...           ...         ...              ...      ...
# 4228   1 stop     DXB          6 hr  288 kg CO2  +203% emissions  ₹58,872
# 4229   1 stop     MCT  20 hr 55 min  274 kg CO2  +188% emissions  ₹65,793
# 4230   1 stop     DOH   8 hr 35 min  323 kg CO2  +240% emissions  ₹75,102
# 4231   1 stop     DOH   2 hr 15 min  306 kg CO2  +221% emissions  ₹75,233
# 4232   1 stop     DOH    3 hr 5 min  312 kg CO2  +228% emissions  ₹84,468
#
# [4233 rows x 12 columns]

# %%
Del_Mum.to_csv('Flights_Del_Mum.csv')

# %%
Date = []
Airline = []
Departure = []
Arrival = []
Duration = []
Route = []
Stops = []
Layover = []
Layover_Time = []
Co2 = []
Emissions = []
Price = []

# %%
option = Options()
option.add_argument('--disable-notifications')
PATH = 'chromedriver.exe'
driver = webdriver.Chrome(PATH,chrome_options=option)
driver.maximize_window()

# %%
data_ready_to_scrap('Bengaluru','Delhi')

# %%
feature_extration()

# %%
Blr_Del = pd.DataFrame()
Blr_Del['Date'] = Date
Blr_Del['Airline']=Airline
Blr_Del['Departure']=Departure
Blr_Del['Arrival']=Arrival
Blr_Del['Duration']=Duration
Blr_Del['Route']=Route
Blr_Del['Stops']=Stops
Blr_Del['Layover']=Layover
Blr_Del['Layover_Time']=Layover_Time
Blr_Del['Co2']=Co2
Blr_Del['Emissions']=Emissions
Blr_Del['Price']=Price
Blr_Del
# Out:
#        Date   Airline Departure    Arrival      Duration    Route    Stops  \
# 0    Aug 15    IndiGo   4:40 AM    7:25 AM   2 hr 45 min  BLR–DEL  Nonstop
# 1    Aug 15  GO FIRST   5:45 AM    8:35 AM   2 hr 50 min  BLR–DEL  Nonstop
# 2    Aug 15   Vistara   7:00 AM    9:40 AM   2 hr 40 min  BLR–DEL  Nonstop
# 3    Aug 15    IndiGo   6:00 AM    8:45 AM   2 hr 45 min  BLR–DEL  Nonstop
# 4    Aug 15    IndiGo   7:45 AM   10:30 AM   2 hr 45 min  BLR–DEL  Nonstop
# ..      ...       ...       ...        ...           ...      ...      ...
# 787  Aug 15  Gulf Air   4:45 AM    8:50 PM   16 hr 5 min  BLR–DEL   1 stop
# 788  Aug 15  Emirates  10:35 AM  2:45 AM+1  16 hr 10 min  BLR–DEL   1 stop
# 789  Aug 15  Emirates  10:35 AM    8:20 PM   9 hr 45 min  BLR–DEL   1 stop
# 790  Aug 15    Etihad   4:40 AM    7:30 PM  14 hr 50 min  BLR–DEL   1 stop
# 791  Aug 15    Etihad   4:40 AM  3:15 AM+1  22 hr 35 min  BLR–DEL   1 stop
#
#     Layover  Layover_Time           Co2          Emissions    Price
# 0         -             -    115 kg CO2      Avg emissions   ₹5,707
# 1         -             -    111 kg CO2      -6% emissions   ₹6,398
# 2         -             -    127 kg CO2      +7% emissions   ₹6,870
# 3         -             -    115 kg CO2      Avg emissions   ₹7,435
# 4         -             -    120 kg CO2      Avg emissions   ₹7,435
# ..      ...           ...           ...                ...      ...
# 787     BAH    7 hr 5 min    473 kg CO2    +298% emissions  ₹54,537
# 788     DXB   9 hr 15 min    367 kg CO2    +208% emissions  ₹63,854
# 789     DXB   2 hr 40 min    367 kg CO2    +208% emissions  ₹67,813
# 790     AUH   7 hr 30 min  1,334 kg CO2  +1,023% emissions  ₹75,389
# 791     AUH  15 hr 15 min  1,245 kg CO2    +948% emissions  ₹75,389
#
# [792 rows x 12 columns]

# %%
Blr_Del.to_csv('Flights_BLR_Del.csv')

# %%
driver.close()

# %%
df = pd.read_csv('Flights_Mum_Del1.csv')

# %%
df1 = pd.read_csv('Flights_Del_Mum.csv')

# %%
df = df.append(df1)
len(df)
# Out:
# 5331

# %%
df1 = pd.read_csv('Flights_BLR_Del.csv')

# %%
df = df.append(df1)
len(df)
# Out:
# 6123

# %%
df
# Out:
#      Unnamed: 0    Date          Airline Departure    Arrival      Duration  \
# 0             0  Aug 15         SpiceJet  12:35 AM    3:00 AM   2 hr 25 min
# 1             1  Aug 15         GO FIRST   8:05 AM   10:15 AM   2 hr 10 min
# 2             2  Aug 15          Vistara   7:30 AM    9:35 AM    2 hr 5 min
# 3             3  Aug 15  AirAsia (India)   3:25 PM   11:10 PM   7 hr 45 min
# 4             4  Aug 15         GO FIRST   6:00 AM    8:05 AM    2 hr 5 min
# ..          ...     ...              ...       ...        ...           ...
# 787         787  Aug 15         Gulf Air   4:45 AM    8:50 PM   16 hr 5 min
# 788         788  Aug 15         Emirates  10:35 AM  2:45 AM+1  16 hr 10 min
# 789         789  Aug 15         Emirates  10:35 AM    8:20 PM   9 hr 45 min
# 790         790  Aug 15           Etihad   4:40 AM    7:30 PM  14 hr 50 min
# 791         791  Aug 15           Etihad   4:40 AM  3:15 AM+1  22 hr 35 min
#
#        Route    Stops Layover  Layover_Time           Co2          Emissions  \
# 0    BOM–DEL  Nonstop       -             -    122 kg CO2     +27% emissions
# 1    BOM–DEL  Nonstop       -             -     83 kg CO2     -12% emissions
# 2    BOM–DEL  Nonstop       -             -    103 kg CO2      +8% emissions
# 3    BOM–DEL   1 stop     JAI   4 hr 50 min    113 kg CO2     +19% emissions
# 4    BOM–DEL  Nonstop       -             -     83 kg CO2     -12% emissions
# ..       ...      ...     ...           ...           ...                ...
# 787  BLR–DEL   1 stop     BAH    7 hr 5 min    473 kg CO2    +298% emissions
# 788  BLR–DEL   1 stop     DXB   9 hr 15 min    367 kg CO2    +208% emissions
# 789  BLR–DEL   1 stop     DXB   2 hr 40 min    367 kg CO2    +208% emissions
# 790  BLR–DEL   1 stop     AUH   7 hr 30 min  1,334 kg CO2  +1,023% emissions
# 791  BLR–DEL   1 stop     AUH  15 hr 15 min  1,245 kg CO2    +948% emissions
#
#        Price
# 0     ₹5,365
# 1     ₹5,390
# 2     ₹5,717
# 3     ₹5,164
# 4     ₹5,390
# ..       ...
# 787  ₹54,537
# 788  ₹63,854
# 789  ₹67,813
# 790  ₹75,389
# 791  ₹75,389
#
# [6123 rows x 13 columns]

# %%
df['Data Scrap Date'] = '20 July 2022'

# %%
df
# Out:
#      Unnamed: 0    Date          Airline Departure    Arrival      Duration  \
# 0             0  Aug 15         SpiceJet  12:35 AM    3:00 AM   2 hr 25 min
# 1             1  Aug 15         GO FIRST   8:05 AM   10:15 AM   2 hr 10 min
# 2             2  Aug 15          Vistara   7:30 AM    9:35 AM    2 hr 5 min
# 3             3  Aug 15  AirAsia (India)   3:25 PM   11:10 PM   7 hr 45 min
# 4             4  Aug 15         GO FIRST   6:00 AM    8:05 AM    2 hr 5 min
# ..          ...     ...              ...       ...        ...           ...
# 787         787  Aug 15         Gulf Air   4:45 AM    8:50 PM   16 hr 5 min
# 788         788  Aug 15         Emirates  10:35 AM  2:45 AM+1  16 hr 10 min
# 789         789  Aug 15         Emirates  10:35 AM    8:20 PM   9 hr 45 min
# 790         790  Aug 15           Etihad   4:40 AM    7:30 PM  14 hr 50 min
# 791         791  Aug 15           Etihad   4:40 AM  3:15 AM+1  22 hr 35 min
#
#        Route    Stops Layover  Layover_Time           Co2          Emissions  \
# 0    BOM–DEL  Nonstop       -             -    122 kg CO2     +27% emissions
# 1    BOM–DEL  Nonstop       -             -     83 kg CO2     -12% emissions
# 2    BOM–DEL  Nonstop       -             -    103 kg CO2      +8% emissions
# 3    BOM–DEL   1 stop     JAI   4 hr 50 min    113 kg CO2     +19% emissions
# 4    BOM–DEL  Nonstop       -             -     83 kg CO2     -12% emissions
# ..       ...      ...     ...           ...           ...                ...
# 787  BLR–DEL   1 stop     BAH    7 hr 5 min    473 kg CO2    +298% emissions
# 788  BLR–DEL   1 stop     DXB   9 hr 15 min    367 kg CO2    +208% emissions
# 789  BLR–DEL   1 stop     DXB   2 hr 40 min    367 kg CO2    +208% emissions
# 790  BLR–DEL   1 stop     AUH   7 hr 30 min  1,334 kg CO2  +1,023% emissions
# 791  BLR–DEL   1 stop     AUH  15 hr 15 min  1,245 kg CO2    +948% emissions
#
#        Price Data Scrap Date
# 0     ₹5,365    20 July 2022
# 1     ₹5,390    20 July 2022
# 2     ₹5,717    20 July 2022
# 3     ₹5,164    20 July 2022
# 4     ₹5,390    20 July 2022
# ..       ...             ...
# 787  ₹54,537    20 July 2022
# 788  ₹63,854    20 July 2022
# 789  ₹67,813    20 July 2022
# 790  ₹75,389    20 July 2022
# 791  ₹75,389    20 July 2022
#
# [6123 rows x 14 columns]

# %%
df.drop('Unnamed: 0',axis=1,inplace=True)

# %%
df
# Out:
#        Date          Airline Departure    Arrival      Duration    Route  \
# 0    Aug 15         SpiceJet  12:35 AM    3:00 AM   2 hr 25 min  BOM–DEL
# 1    Aug 15         GO FIRST   8:05 AM   10:15 AM   2 hr 10 min  BOM–DEL
# 2    Aug 15          Vistara   7:30 AM    9:35 AM    2 hr 5 min  BOM–DEL
# 3    Aug 15  AirAsia (India)   3:25 PM   11:10 PM   7 hr 45 min  BOM–DEL
# 4    Aug 15         GO FIRST   6:00 AM    8:05 AM    2 hr 5 min  BOM–DEL
# ..      ...              ...       ...        ...           ...      ...
# 787  Aug 15         Gulf Air   4:45 AM    8:50 PM   16 hr 5 min  BLR–DEL
# 788  Aug 15         Emirates  10:35 AM  2:45 AM+1  16 hr 10 min  BLR–DEL
# 789  Aug 15         Emirates  10:35 AM    8:20 PM   9 hr 45 min  BLR–DEL
# 790  Aug 15           Etihad   4:40 AM    7:30 PM  14 hr 50 min  BLR–DEL
# 791  Aug 15           Etihad   4:40 AM  3:15 AM+1  22 hr 35 min  BLR–DEL
#
#        Stops Layover  Layover_Time           Co2          Emissions    Price  \
# 0    Nonstop       -             -    122 kg CO2     +27% emissions   ₹5,365
# 1    Nonstop       -             -     83 kg CO2     -12% emissions   ₹5,390
# 2    Nonstop       -             -    103 kg CO2      +8% emissions   ₹5,717
# 3     1 stop     JAI   4 hr 50 min    113 kg CO2     +19% emissions   ₹5,164
# 4    Nonstop       -             -     83 kg CO2     -12% emissions   ₹5,390
# ..       ...     ...           ...           ...                ...      ...
# 787   1 stop     BAH    7 hr 5 min    473 kg CO2    +298% emissions  ₹54,537
# 788   1 stop     DXB   9 hr 15 min    367 kg CO2    +208% emissions  ₹63,854
# 789   1 stop     DXB   2 hr 40 min    367 kg CO2    +208% emissions  ₹67,813
# 790   1 stop     AUH   7 hr 30 min  1,334 kg CO2  +1,023% emissions  ₹75,389
# 791   1 stop     AUH  15 hr 15 min  1,245 kg CO2    +948% emissions  ₹75,389
#
#     Data Scrap Date
# 0      20 July 2022
# 1      20 July 2022
# 2      20 July 2022
# 3      20 July 2022
# 4      20 July 2022
# ..              ...
# 787    20 July 2022
# 788    20 July 2022
# 789    20 July 2022
# 790    20 July 2022
# 791    20 July 2022
#
# [6123 rows x 13 columns]

# %%
df.to_csv('Flight_Details_Aggrigated.csv')

# %%
df
# Out:
#        Date          Airline Departure    Arrival      Duration    Route  \
# 0    Aug 15         SpiceJet  12:35 AM    3:00 AM   2 hr 25 min  BOM–DEL
# 1    Aug 15         GO FIRST   8:05 AM   10:15 AM   2 hr 10 min  BOM–DEL
# 2    Aug 15          Vistara   7:30 AM    9:35 AM    2 hr 5 min  BOM–DEL
# 3    Aug 15  AirAsia (India)   3:25 PM   11:10 PM   7 hr 45 min  BOM–DEL
# 4    Aug 15         GO FIRST   6:00 AM    8:05 AM    2 hr 5 min  BOM–DEL
# ..      ...              ...       ...        ...           ...      ...
# 787  Aug 15         Gulf Air   4:45 AM    8:50 PM   16 hr 5 min  BLR–DEL
# 788  Aug 15         Emirates  10:35 AM  2:45 AM+1  16 hr 10 min  BLR–DEL
# 789  Aug 15         Emirates  10:35 AM    8:20 PM   9 hr 45 min  BLR–DEL
# 790  Aug 15           Etihad   4:40 AM    7:30 PM  14 hr 50 min  BLR–DEL
# 791  Aug 15           Etihad   4:40 AM  3:15 AM+1  22 hr 35 min  BLR–DEL
#
#        Stops Layover  Layover_Time           Co2          Emissions    Price  \
# 0    Nonstop       -             -    122 kg CO2     +27% emissions   ₹5,365
# 1    Nonstop       -             -     83 kg CO2     -12% emissions   ₹5,390
# 2    Nonstop       -             -    103 kg CO2      +8% emissions   ₹5,717
# 3     1 stop     JAI   4 hr 50 min    113 kg CO2     +19% emissions   ₹5,164
# 4    Nonstop       -             -     83 kg CO2     -12% emissions   ₹5,390
# ..       ...     ...           ...           ...                ...      ...
# 787   1 stop     BAH    7 hr 5 min    473 kg CO2    +298% emissions  ₹54,537
# 788   1 stop     DXB   9 hr 15 min    367 kg CO2    +208% emissions  ₹63,854
# 789   1 stop     DXB   2 hr 40 min    367 kg CO2    +208% emissions  ₹67,813
# 790   1 stop     AUH   7 hr 30 min  1,334 kg CO2  +1,023% emissions  ₹75,389
# 791   1 stop     AUH  15 hr 15 min  1,245 kg CO2    +948% emissions  ₹75,389
#
#     Data Scrap Date
# 0      20 July 2022
# 1      20 July 2022
# 2      20 July 2022
# 3      20 July 2022
# 4      20 July 2022
# ..              ...
# 787    20 July 2022
# 788    20 July 2022
# 789    20 July 2022
# 790    20 July 2022
# 791    20 July 2022
#
# [6123 rows x 13 columns]
